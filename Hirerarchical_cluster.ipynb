# %% [markdown]
# <a href="https://colab.research.google.com/github/alishas2005/alishass/blob/main/Hirerarchical_cluster.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.cluster.hierarchy as sc
from sklearn.cluster import AgglomerativeClustering

# %%
dataset = pd.read_csv("/content/Iris.csv")

# %%
dataset.head(3)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa

# %%
dataset.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
sns.pairplot(data=dataset)
plt.show()

# %%
numeric_data = dataset.iloc[:, :-1]

# %%
linked = sc.linkage(numeric_data, method="ward", metric="euclidean")

# %%
sc.dendrogram(linked)
plt.figure(figsize=(20,20))
plt.show()
plt.savefig("demo.jpg")

# %%
ac = AgglomerativeClustering(n_clusters=3,linkage='single')
dataset["Predict"]=ac.fit_predict(numeric_data)

# %%
dataset.head(2)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
#
#    Predict
# 0        1
# 1        1

# %%
sns.pairplot(data=dataset,hue="Predict")
plt.show()

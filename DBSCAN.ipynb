# %% [markdown]
# <a href="https://colab.research.google.com/github/alishas2005/alishass/blob/main/DBSCAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_moons
import pandas as pd
from sklearn.cluster import DBSCAN

# %%
x,y = make_moons(n_samples=250, noise=0.05)

# %%
df = {"data1":x[:,0],"data2":x[:,1]}

# %%
dataset = pd.DataFrame(df)

# %%
dataset.head(3)
# Out:
#       data1     data2
# 0  0.872747  0.398221
# 1  1.808146 -0.057854
# 2 -1.035555  0.179906

# %%
sns.scatterplot(x="data1",y="data2",data=dataset)
# Out:
# <Axes: xlabel='data1', ylabel='data2'>

# %%
db = DBSCAN(eps=0.5,min_samples=5)
dataset["Predict"] = db.fit_predict(dataset)

# %%
sns.scatterplot(x="data1",y="data2",data=dataset,hue=y)
# Out:
# <Axes: xlabel='data1', ylabel='data2'>

# %% [markdown]
# <a href="https://colab.research.google.com/github/alishas2005/alishass/blob/main/Cross_Validation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import LeaveOneOut, LeavePOut, KFold,StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression

# %%
dataset = pd.read_csv("/content/placement.csv")

# %%
dataset.head(3)
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1

# %%
x =  dataset.iloc[:,:-1]
y = dataset["resume_score"]

# %%
new_data = dataset.head()

# %%
lo = KFold(n_splits=5)
for train, test in lo.split(x_new,y_new):
  print(train,test)
# Out:
# [1 2 3 4] [0]
# [0 2 3 4] [1]
# [0 1 3 4] [2]
# [0 1 2 4] [3]
# [0 1 2 3] [4]

# %%
x_new = new_data.iloc[:,:-1]
y_new = new_data["resume_score"]

# %%
new_data
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
p=cross_val_score(LinearRegression(),x,y,cv=KFold(n_splits=10))

# %%
p.sort()
p*100
# Out:
# array([100., 100., 100., 100., 100., 100., 100., 100., 100., 100.])
